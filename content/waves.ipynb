# %% [markdown]
# <h1 style="color: rgb(0, 91, 94);">Waves</h1>
#
# <hr style="border-top: 1px solid rgb(0, 91, 94);" />
#
#
# In this notebook, you will learn about waves. Once you get to the end you should be able to:
#
# 1. Describe sine waves.
# 2. Visualise sine waves.
# 3. Visualise the relationship between circles and sine waves.
# 4. Describe how lienar combination of sine waves approximate other functions.

# %%
# Efficient numerical arrays.
import numpy as np

# %%
# Plotting.
import matplotlib.pyplot as plt

# %%
# Make plots a little nicer.
plt.style.use('seaborn-deep')

# %%
# A range of x values for plotting functions.
x = np.linspace(-10.0, 10.0, 1000)

# %%
# Sin wave.
y_sin = np.sin(x)

# Cos wave.
y_cos = np.cos(x)

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot sin wave.
ax.plot(x, y_sin, color='mediumvioletred', label='$sin(x)$')

# Plot cos wave.
ax.plot(x, y_cos, color='rebeccapurple', label='$cos(x)$')

# Draw vertical lines at -pi and pi.
plt.axvline(x=0, color='slategrey', linestyle='--', label='$0$')
plt.axvline(x=2*np.pi, color='seagreen', linestyle='--', label='$2\pi$')

# Show legend.
ax.legend();

# %%
# Sin wave.
y_sin = np.sin(x)

# 2Sin wave.
y_2sin = 2.0 * np.sin(x)

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot Sin wave.
ax.plot(x, y_sin, color='mediumvioletred', label='$\sin(x)$')

# Plot 2Sin wave.
ax.plot(x, y_2sin, color='rebeccapurple', label='$2 \sin(x)$')

# Draw vertical lines at -pi and pi.
plt.axvline(x=0, color='slategrey', linestyle='--', label='$0$')
plt.axvline(x=2*np.pi, color='seagreen', linestyle='--', label='$2\pi$')

# Show legend.
ax.legend();

# %%
# Sin wave.
y_sin = np.sin(x)

# Sin2 wave.
y_sin2 = np.sin(x)**2

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot Sin wave.
ax.plot(x, y_sin, color='mediumvioletred', label='$\sin(x)$')

# Plot Sin2 wave.
ax.plot(x, y_sin2, color='lightseagreen', label='$\sin^2(x)$')

# Draw vertical lines at -pi and pi.
plt.axvline(x=0, color='slategrey', linestyle='--', label='$0$')
plt.axvline(x=2*np.pi, color='seagreen', linestyle='--', label='$2\pi$')

# Show legend.
ax.legend();

# %%
# Sin wave.
y_sin = np.sin(x)

# Sin+2 wave.
y_sinp2 = np.sin(x + 2)

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot Sin wave.
ax.plot(x, y_sin, color='mediumvioletred', label='$\sin(x)$')

# Plot Sin+2 wave.
ax.plot(x, y_sinp2, color='chocolate', label='$\sin(x + 2)$')

# Draw vertical lines at -pi and pi.
plt.axvline(x=0, color='slategrey', linestyle='--', label='$0$')
plt.axvline(x=2*np.pi, color='seagreen', linestyle='--', label='$2\pi$')

# Show legend.
ax.legend();

# %%
# Sin wave.
y_sin = np.sin(x)

# 2Sin wave.
y_2sin = 2.0 * np.sin(x)

# Sin2 wave.
y_sin2 = np.sin(x)**2

# Sin+2 wave.
y_sinp2 = np.sin(x + 2)

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot Sin wave.
ax.plot(x, y_sin, color='mediumvioletred', label='$\sin(x)$')

# Plot 2Sin wave.
ax.plot(x, y_2sin, color='rebeccapurple', label='$2 \sin(x)$')

# Plot Sin2 wave.
ax.plot(x, y_sin2, color='lightseagreen', label='$\sin^2(x)$')

# Plot Sin+2 wave.
ax.plot(x, y_sinp2, color='chocolate', label='$\sin(x + 2)$')

# Draw vertical lines at -pi and pi.
plt.axvline(x=0, color='slategrey', linestyle='--', label='$0$')
plt.axvline(x=2*np.pi, color='seagreen', linestyle='--', label='$2\pi$')

# Show legend.
ax.legend();

# %%
# Sin wave.
y_sin = np.sin(x)

# Sin+pi wave.
y_sinpi = np.sin(x + np.pi)

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot Sin wave.
ax.plot(x, y_sin, color='mediumvioletred', label='$\sin(x)$')

# Plot Sin+2 wave.
ax.plot(x, y_sinpi, color='chocolate', label='$\sin(x + \pi)$')

# Draw vertical lines at -pi and pi.
plt.axvline(x=0, color='slategrey', linestyle='--', label='$0$')
plt.axvline(x=2*np.pi, color='seagreen', linestyle='--', label='$2\pi$')

# Show legend.
ax.legend();

# %%
# Sin wave.
y_sin = np.sin(x)

# Sin+pi/2 wave.
y_sinpio2 = np.sin(x + (0.5 * np.pi))

# Cos wave.
y_cos = np.cos(x)

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot Sin wave.
ax.plot(x, y_sin, color='mediumvioletred', label='$\sin(x)$')

# Plot Sin+2 wave.
ax.plot(x, y_sinpio2, color='chocolate', label='$\sin(x + 0.5 \pi)$')

# Plot Cos wave.
ax.plot(x, y_cos, color='indigo', label='$\cos(x)$')

# Draw vertical lines at -pi and pi.
plt.axvline(x=0, color='slategrey', linestyle='--', label='$0$')
plt.axvline(x=2*np.pi, color='seagreen', linestyle='--', label='$2\pi$')

# Show legend.
ax.legend();

# %% [markdown]
# ## Sum of Waves
#
# ***

# %%
# A range of x values for plotting functions.
x = np.linspace(-np.pi, 6.0 * np.pi, 1000)

# Waves.
ys = np.vstack([
    np.sin(x),
    3.0 * np.sin(x) + 1.0,
    np.sin(x + 1.0)**2,
    np.sin(2.0 * x),
])

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

for y in ys:
    # Plot component wave.
    ax.plot(x, y, color='lightslategrey', linestyle=':')

# Plot sum wave.
ax.plot(x, ys.sum(axis=0), color='deeppink', label=r'$\Sigma$')

# Draw vertical lines at -pi and pi.
plt.axvline(x=0, color='teal', linestyle='--')
plt.axvline(x=2*np.pi, color='teal', linestyle='--')

# Show legend.
ax.legend();

# %% [markdown]
# <br>
#
# ## Waves with Similar Wavelengths
#
# ***

# %%
# Factor.
f = 0.95

# A range of x values for plotting functions.
x = np.linspace(-60.0 * np.pi, 60.0 * np.pi, 1000)

# Sin wave.
y_sinA = np.sin(x)

# Sin wave.
y_sinB = np.sin(x * f)

# Sum.
y_sum = y_sinA + y_sinB

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot Sin wave.
# ax.plot(x, y_sinA, color='teal', label='$\sin(x)$', linestyle=':')

# Plot Sin+2 wave.
# ax.plot(x, y_sinB, color='chocolate', label=f'$\sin(x * {f})$', linestyle=':')

# Plot the sum.
ax.plot(x, y_sum, color='mediumvioletred', label=fr'$\sin(x) + \sin({f} x)$')


# Show legend.
ax.legend();

# %%
(np.exp(-1.0j * 2.0 * np.pi / len(y_sum) * np.arange(len(y_sum))))
# Out:
# array([ 1.00000000e+00+0.00000000e+00j,  9.99980261e-01-6.28314397e-03j,
#         9.99921044e-01-1.25660399e-02j,  9.99822352e-01-1.88484397e-02j,
#         9.99684189e-01-2.51300954e-02j,  9.99506560e-01-3.14107591e-02j,
#         9.99289473e-01-3.76901827e-02j,  9.99032935e-01-4.39681183e-02j,
#         9.98736957e-01-5.02443182e-02j,  9.98401550e-01-5.65185345e-02j,
#         9.98026728e-01-6.27905195e-02j,  9.97612506e-01-6.90600257e-02j,
#         9.97158900e-01-7.53268055e-02j,  9.96665928e-01-8.15906116e-02j,
#         9.96133609e-01-8.78511966e-02j,  9.95561965e-01-9.41083133e-02j,
#         9.94951017e-01-1.00361715e-01j,  9.94300790e-01-1.06611154e-01j,
#         9.93611311e-01-1.12856385e-01j,  9.92882605e-01-1.19097160e-01j,
#         9.92114701e-01-1.25333234e-01j,  9.91307631e-01-1.31564359e-01j,
#         9.90461426e-01-1.37790291e-01j,  9.89576119e-01-1.44010783e-01j,
#         9.88651745e-01-1.50225589e-01j,  9.87688341e-01-1.56434465e-01j,
# ...

# %%
# Discrete Fourier Transform.
y_dft = np.zeros(len(y_sum), dtype=np.clongdouble)
for k in range(len(y_sum)):
    y_dft[k] = np.sum(y_sum * np.exp(-1.0j * 2.0 * np.pi * k / len(y_sum) * np.arange(len(y_sum))))
y_dft
# Out:
# array([-3.55271368e-15+0.00000000e+00j, -2.78668005e-06+8.87024914e-04j,
#        -1.11756282e-05+1.77863306e-03j, -2.52539897e-05+2.67945220e-03j,
#        -4.51684264e-05+3.59419996e-03j, -7.11272774e-05+4.52773069e-03j,
#        -1.03403657e-04+5.48508469e-03j, -1.42339562e-04+6.47154080e-03j,
#        -1.88351076e-04+7.49267321e-03j, -2.41934823e-04+8.55441368e-03j,
#        -3.03675794e-04+9.66312045e-03j, -3.74256781e-04+1.08256552e-02j,
#        -4.54469641e-04+1.20494701e-02j, -5.45228696e-04+1.33427062e-02j,
#        -6.47586659e-04+1.47143072e-02j, -7.62753511e-04+1.61741491e-02j,
#        -8.92118913e-04+1.77331917e-02j, -1.03727885e-03+1.94036547e-02j,
#        -1.20006731e-03+2.11992238e-02j, -1.38259416e-03+2.31352943e-02j,
#        -1.58729042e-03+2.52292588e-02j, -1.81696266e-03+2.75008493e-02j,
#        -2.07485862e-03+2.99725477e-02j, -2.36474660e-03+3.26700771e-02j,
#        -2.69101204e-03+3.56229976e-02j, -3.05877560e-03+3.88654291e-02j,
# ...

# %%
# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot the sum.
ax.plot(x, y_dft.real, color='mediumvioletred')

# %%
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(projection='3d')

ax.plot3D(x, y_dft.real, y_dft.imag);

# %% [markdown]
# ## Complex Waves
#
# https://jakevdp.github.io/PythonDataScienceHandbook/04.12-three-dimensional-plotting.html
#
# ***

# %%
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(projection='3d')

x = np.linspace(0, 10.0 * np.pi, 1000)

# f(x) = cos(x) + i sin(x)
y = np.cos(x)
z = np.sin(x)

ax.plot3D(x, y, z);

# %%
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(projection='3d')

x = np.linspace(0, 10.0 * np.pi, 1000)
# f(x) = e^ix
y = np.exp(1.0j * x)

ax.plot3D(x, y.real, y.imag);

# %%
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

x = np.linspace(-6, 6, 30)
y = np.linspace(-6, 6, 30)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure(figsize=(20, 8))
ax = fig.add_subplot(projection='3d')

ax.contour3D(X, Y, Z, 800, cmap='winter')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z');

# %% [markdown]
# <br>
#
# # Audio
#
# ***

# %%
import IPython.display as display

# %%
# https://stackoverflow.com/a/39615379
wave_audio = np.sin(np.linspace(0, 3000, 20000))
display.Audio(wave_audio, rate=20000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Factor.
f = 0.95

# A range of x values for plotting functions.
x = np.linspace(0, 5000, 20000)

# Sin wave.
y_sinA = np.sin(x)

# Sin wave.
y_sinB = np.sin(x * f)

# Sum.
y_sum = y_sinA + y_sinB

# Create new plot.
fig, ax = plt.subplots(figsize=(20, 8))

# Plot the sum.
ax.plot(x, y_sum, color='mediumvioletred', label=fr'$\sin(x) + \sin({f} x)$')


# Show legend.
ax.legend();

display.Audio(y_sum, rate=3000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
framerate = 44100
t = np.linspace(0,5,framerate*5)
data = np.sin(2*np.pi*220*t) + np.sin(2*np.pi*224*t)
display.Audio(data, rate=framerate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <hr style="border-top: 1px solid rgb(0, 91, 94);" />
#
# <h2 style="color: rgb(0, 91, 94);">End</h2>
